# %%
pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/YOLOV8'
# Out:
# /content/drive/MyDrive/YOLOV8

# %%
# !ls
# Out:
# 'Copy of yolov7.ipynb'	 yolov7_main2-20230426T105950Z-001.zip	 yolov8n.pt
#  data			 YOLOV8.ipynb				 yolov8s.pt
#  data.yaml		 yolov8l.pt				 yolov8x.pt
#  runs			 yolov8m.pt

# %% [markdown]
# YOLOV8s (Batch-16)

# %%
# %cd '/content/drive/MyDrive/YOLOV8'

! yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=40 imgsz=416 plots=true
# Out:
# /content/drive/MyDrive/YOLOV8
# Ultralytics YOLOv8.0.88 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# YOLOV8m (Batch-16)

# %%
# %cd '/content/drive/MyDrive/YOLOV8'

! yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=40 imgsz=416 plots=true
# Out:
# /content/drive/MyDrive/YOLOV8
# Ultralytics YOLOv8.0.88 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# YOLOV8l (Batch-16)

# %%
# %cd '/content/drive/MyDrive/YOLOV8'

! yolo task=detect mode=train model=yolov8l.pt data=data.yaml epochs=40 imgsz=416 plots=true
# Out:
# /content/drive/MyDrive/YOLOV8
# Ultralytics YOLOv8.0.88 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# YOLOV8x (Batch-16)

# %%
# %cd '/content/drive/MyDrive/YOLOV8'

! yolo task=detect mode=train model=yolov8x.pt data=data.yaml epochs=40 imgsz=416 plots=true
# Out:
# /content/drive/MyDrive/YOLOV8
# Ultralytics YOLOv8.0.88 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# YOLOV8s (Batch-30)

# %%
# %cd '/content/drive/MyDrive/YOLOV8'

! yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=40 imgsz=416 plots=true batch=30
# Out:
# /content/drive/MyDrive/YOLOV8
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# YOLOV8m (Batch-30)

# %%
# %cd '/content/drive/MyDrive/YOLOV8'

! yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=40 imgsz=416 plots=true batch=30
# Out:
# /content/drive/MyDrive/YOLOV8
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# YOLOV8l (Batch-30)

# %%
# %cd '/content/drive/MyDrive/YOLOV8'

! yolo task=detect mode=train model=yolov8l.pt data=data.yaml epochs=40 imgsz=416 plots=true batch=30
# Out:
# /content/drive/MyDrive/YOLOV8
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# YOLOV8x (Batch-30)

# %%
# %cd '/content/drive/MyDrive/YOLOV8'

! yolo task=detect mode=train model=yolov8x.pt data=data.yaml epochs=40 imgsz=416 plots=true batch=30
# Out:
# /content/drive/MyDrive/YOLOV8
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
